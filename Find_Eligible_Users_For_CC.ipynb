# %%
customer_ids = ["001", "002", "003", "004", "005", "006"]
customer_credit_scores = ["634", "360", "760", "801", "489", "675"]
customer_annual_salary = ["3000000", "2100000", "1000000", "800000", "6000000", "4200000"]
customer_age = ["32", "34", "43", "34", "45", "33"]
customer_having_no_of_creditcards = ["3", "1", "4", "2", "1", "3"]

customer_details = {
    "CUSTID": customer_ids,
    "Credit_Score": customer_credit_scores,
    "Annual_Salary": customer_annual_salary,
    "Age": customer_age,
    "No_of_credit_Cards": customer_having_no_of_creditcards}

# print the customer_details
print(customer_details)
# Out:
# {'CUSTID': ['001', '002', '003', '004', '005', '006'], 'Credit_Score': ['634', '360', '760', '801', '489', '675'], 'Annual_Salary': ['3000000', '2100000', '1000000', '800000', '6000000', '4200000'], 'Age': ['32', '34', '43', '34', '45', '33'], 'No_of_credit_Cards': ['3', '1', '4', '2', '1', '3']}

# %%
import numpy as np
customer_data_array = np.array(list(customer_details.values())).T
print(customer_data_array)
# Out:
# [['001' '634' '3000000' '32' '3']
#  ['002' '360' '2100000' '34' '1']
#  ['003' '760' '1000000' '43' '4']
#  ['004' '801' '800000' '34' '2']
#  ['005' '489' '6000000' '45' '1']
#  ['006' '675' '4200000' '33' '3']]
